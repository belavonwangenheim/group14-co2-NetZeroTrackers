# %%
import pandas as pd

# Gemergte Datei laden (co2-total & World Energy Consumption)
df_merged = pd.read_csv('../data/merge/co2_wec_merged.csv')
print("Datei geladen:", df_merged.shape)
display(df_merged.head())
# Out:
# Datei geladen: (9540, 19)
#      Country_x ISO3  Year     Total      Coal       Oil       Gas    Cement  \
# 0  Afghanistan  AFG  1980  1.756302  0.315762  0.925256  0.187254  0.023284
# 1  Afghanistan  AFG  1981  1.978463  0.333424  1.014928  0.304112  0.032879
# 2  Afghanistan  AFG  1982  2.094581  0.384720  0.992944  0.395712  0.039077
# 3  Afghanistan  AFG  1983  2.519954  0.384720  1.220112  0.615552  0.006450
# 4  Afghanistan  AFG  1984  2.821540  0.392556  1.133644  0.931863  0.047963
#
#     Flaring  Other  PerCapita    Country_y  PrimaryEnergy  FossilEnergy  \
# 0  0.304747    0.0   0.140655  Afghanistan          7.791           0.0
# 1  0.293120    0.0   0.177358  Afghanistan          8.777           0.0
# 2  0.282128    0.0   0.207625  Afghanistan          9.348           0.0
# 3  0.293120    0.0   0.253225  Afghanistan         11.436           0.0
# 4  0.315513    0.0   0.275442  Afghanistan         11.489           0.0
#
# ...
