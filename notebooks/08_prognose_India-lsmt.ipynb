# %%
import os
print(os.getcwd())
# Out:
# /Users/jana/Downloads/group14-co2-NetZeroTrackers

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# CSV einlesen
df = pd.read_csv('data/processed/india_model_dataset.csv')

# Historische Daten für später
historical_data = df[df['Year'] <= 2017]
years_historical = historical_data['Year'].values
true_total = historical_data['CO2_total'].values

# Ursprüngliche Features
base_features = [
    'GDP', 'Population', 'Primary_energy', 'Energy_intensity',
    'Urban_population_pct', 'Trade_share_GDP', 'GDP_growth_annual'
]

# Rolling Average anwenden
df[base_features] = df[base_features].rolling(window=3, min_periods=1).mean()

# Lags erzeugen (Lag 1 & 2 für ausgewählte Features)
lag_features = ['GDP', 'Energy_intensity']
for col in lag_features:
    for lag in [1, 2]:
        df[f"{col}_lag{lag}"] = df[col].shift(lag)

# NaNs entfernen
df.dropna(inplace=True)

# Input-Features aktualisieren
input_features = base_features + [f"{col}_lag{lag}" for col in lag_features for lag in [1, 2]]

# Zielvariablen
target_columns = ['CO2_coal', 'CO2_oil', 'CO2_gas', 'CO2_cement']

# Daten bis 2017
df_model = df[df['Year'] <= 2017].copy()

# Skalierung
feature_scaler = MinMaxScaler()
target_scaler = MinMaxScaler()

X_scaled = feature_scaler.fit_transform(df_model[input_features])
y_scaled = target_scaler.fit_transform(df_model[target_columns])

# Fenstergröße
window_size = 10
X_seq, y_seq = [], []
for i in range(len(X_scaled) - window_size):
    X_seq.append(X_scaled[i:i + window_size])
    y_seq.append(y_scaled[i + window_size])

X_seq = np.array(X_seq)
y_seq = np.array(y_seq)

# Train/Test Split (zeitlich korrekt)
n_train = df_model[df_model['Year'] <= 2005].shape[0]
X_train = X_seq[:n_train - window_size]
y_train = y_seq[:n_train - window_size]
X_test = X_seq[n_train - window_size:]
y_test = y_seq[n_train - window_size:]

# Modell
model = Sequential()
model.add(LSTM(units=64, return_sequences=True, input_shape=(window_size, len(input_features))))
model.add(Dropout(0.3))
model.add(LSTM(units=32))
model.add(Dropout(0.3))
model.add(Dense(units=len(target_columns)))

model.compile(optimizer='adam', loss='mse', metrics=['mae'])

early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# Training
history = model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=500,
    batch_size=4,
    callbacks=[early_stopping],
    verbose=1
)

# Vorhersage auf dem Testdatensatz (skaliert)
y_pred_scaled = model.predict(X_test)

# Rücktransformation in Originaleinheiten
y_pred = target_scaler.inverse_transform(y_pred_scaled)
y_true = target_scaler.inverse_transform(y_test)

# Rücktransformation in Originaleinheiten
y_pred = target_scaler.inverse_transform(y_pred_scaled)
y_true = target_scaler.inverse_transform(y_test)

# Fehler-Metriken pro Zielvariable (CO₂-Komponenten)
for i, col in enumerate(target_columns):
    mae = mean_absolute_error(y_true[:, i], y_pred[:, i])
    rmse = np.sqrt(mean_squared_error(y_true[:, i], y_pred[:, i]))
    r2 = r2_score(y_true[:, i], y_pred[:, i])

    print(f"{col}:")
    print(f"  Mittlere absolute Abweichung (MAE): {mae:.2f}")
    print(f"  Root Mean Squared Error (RMSE): {rmse:.2f}")
    print(f"  Bestimmtheitsmaß (R²): {r2:.3f}\n")

# Zeitraum 2013–2017 extrahieren
trend_df = df[(df['Year'] >= 2013) & (df['Year'] <= 2017)].reset_index(drop=True)

# Spalten, für die die Wachstumsrate berechnet werden soll
columns_to_analyze = [
    'GDP', 'Population', 'Primary_energy', 'Energy_intensity',
    'CO2_coal', 'CO2_oil', 'CO2_gas', 'CO2_cement',
    'Urban_population_pct', 'Trade_share_GDP', 'GDP_growth_annual'
]

# Wachstumsraten berechnen
trend_results = []
for col in columns_to_analyze:
    start_value = trend_df.iloc[0][col]
    end_value = trend_df.iloc[-1][col]
    n_years = trend_df.iloc[-1]['Year'] - trend_df.iloc[0]['Year']
    growth_rate = (end_value / start_value) ** (1 / n_years) - 1
    trend_results.append({
        'Feature': col,
        'Startwert': start_value,
        'Endwert': end_value,
        'Jahreswachstum': growth_rate
    })

# In DataFrame umwandeln und runden
trend_table = pd.DataFrame(trend_results)
trend_table['Jahreswachstum'] = (trend_table['Jahreswachstum'] * 100).round(3)  # in Prozent
trend_table = trend_table.round(2)

# Tabelle anzeigen
print(trend_table)

# Wachstumsraten als Dictionary (dezimal)
growth = dict(zip(trend_table['Feature'], (trend_table['Jahreswachstum'] / 100).values))

import os

# Zielvariablen definieren
target_columns = ['CO2_coal', 'CO2_oil', 'CO2_gas', 'CO2_cement']

# Prognosezeitraum
future_years = list(range(2018, 2051))

# Wachstumsraten für BAU – für India (Durchschnitt 2013–2017)
growth = {
    'GDP': 0.0716,                  # 7.16 %
    'Population': 0.0125,           # 1.25 %
    'Primary_energy': 0.0461,       # 4.61 %
    'Energy_intensity': -0.0235,    # -2.35 %
    'CO2_coal': 0.0500,             # 5.00 %
    'CO2_oil': 0.0622,              # 6.22 %
    'CO2_gas': 0.0181,              # 1.81 %
    'CO2_cement': 0.0294,           # 2.94 %
    'Urban_population_pct': 0.0120, # 1.20 %
    'Trade_share_GDP': -0.0715,     # -7.15 %
    'GDP_growth_annual': 0.0811     # 8.11 %
}

# Letzter bekannter Datenpunkt (2017)
last_row = df_model[input_features + target_columns].iloc[-1].copy()
last_row['Year'] = 2017
last_row['CO2_total'] = last_row['CO2_coal'] + last_row['CO2_oil'] + last_row['CO2_gas'] + last_row['CO2_cement']

bau = last_row.copy()
measures = last_row.copy()

bau_rows = []
measure_rows = []

# Iteration über Zieljahre
for year in future_years:
    # BAU – normales Wachstum
    row_bau = bau.copy()
    row_bau['Year'] = year
    for key in growth:
        if key in row_bau:
            row_bau[key] *= (1 + growth[key])

    # Maßnahmen – direkte Eingriffe
    row_mea = measures.copy()
    row_mea['Year'] = year

    # Allgemeine wirtschaftliche Variablen (etwas abgeschwächt)
    row_mea['GDP'] *= 1.02
    row_mea['Population'] *= 1.006
    row_mea['Urban_population_pct'] *= 1.0226
    row_mea['Trade_share_GDP'] *= 0.9492
    row_mea['Primary_energy'] *= 0.98  # optionaler Rückgang

    # CO₂-Eingriffe
    if year >= 2018:
        row_mea['CO2_coal'] *= (1 - 0.02)  # -2 %/Jahr ab 2018

    if year >= 2025:
        row_mea['CO2_oil'] *= (1 - 0.015)  # -1.5 %/Jahr
        base_energy_intensity = row_mea['Energy_intensity'] / (1 + growth['Energy_intensity'])
        row_mea['Energy_intensity'] = base_energy_intensity * (1 - 0.06)  # -6 %/Jahr
        base_cement = row_mea['CO2_cement'] / (1 + growth['CO2_cement'])
        row_mea['CO2_cement'] = base_cement * (1 - 0.005)  # -0.5 %/Jahr

    if year >= 2030:
        base_gas = row_mea['CO2_gas'] / (1 + growth['CO2_gas'])
        row_mea['CO2_gas'] = base_gas * (1 + 0.005)  # leicht +0.5 % pro Jahr

    # CO2_total jeweils berechnen
    row_bau['CO2_total'] = row_bau['CO2_coal'] + row_bau['CO2_oil'] + row_bau['CO2_gas'] + row_bau['CO2_cement']
    row_mea['CO2_total'] = row_mea['CO2_coal'] + row_mea['CO2_oil'] + row_mea['CO2_gas'] + row_mea['CO2_cement']

    # Speichern
    bau_rows.append(row_bau.copy())
    measure_rows.append(row_mea.copy())

    # Update für nächste Iteration
    bau = row_bau.copy()
    measures = row_mea.copy()

# DataFrames erzeugen
df_bau_direct = pd.DataFrame(bau_rows)
df_mea_direct = pd.DataFrame(measure_rows)

# Vorschau
print("\nSzenario A – Business as Usual (direkte Entwicklung):")
df_bau_direct['Year'] = df_bau_direct['Year'].astype(int)
print(df_bau_direct[['Year', 'CO2_total', 'CO2_coal', 'CO2_oil', 'CO2_gas', 'CO2_cement']].to_string(index=False))

print("\nSzenario B – Mit Maßnahmen (direkte Eingriffe):")
df_mea_direct['Year'] = df_mea_direct['Year'].astype(int)
print(df_mea_direct[['Year', 'CO2_total', 'CO2_coal', 'CO2_oil', 'CO2_gas', 'CO2_cement']].to_string(index=False))

# Ergebnisordner erstellen und speichern
output_folder = '../data/results/szenario_prognose_india_lsmt/'
os.makedirs(output_folder, exist_ok=True)

df_bau_direct.to_csv(os.path.join(output_folder, 'india_bau.csv'), index=False)
df_mea_direct.to_csv(os.path.join(output_folder, 'india_measures.csv'), index=False)

print(f"\n Prognosedateien gespeichert in: {output_folder}")

# Plot-Stil
plt.figure(figsize=(12, 6))

# Historische Daten bis 2017
plt.plot(historical_data['Year'], historical_data['CO2_total'], label='Historische CO₂-Werte', color='tab:blue')

# Prognose – BAU
plt.plot(df_bau_direct['Year'], df_bau_direct['CO2_total'], linestyle='--', color='tab:orange', label='Szenario A – Business as Usual')

# Prognose – Maßnahmen
plt.plot(df_mea_direct['Year'], df_mea_direct['CO2_total'], linestyle='--', color='tab:green', label='Szenario B – Mit Maßnahmen')

# Titel und Achsenbeschriftungen
plt.title('Szenarienvergleich: LSTM-Prognose der CO₂-Gesamtemissionen für India')
plt.xlabel('Jahr')
plt.ylabel('CO₂ total [Mt]')

# Legende
plt.legend()

# Achsenbegrenzung optional
plt.ylim(bottom=0)

# Raster
plt.grid(True, linestyle='--', alpha=0.5)

# Anzeigen
plt.tight_layout()
plt.show()

import matplotlib.pyplot as plt

# Farben pro Komponente – konsistent
colors = {
    'CO2_coal': 'tab:gray',
    'CO2_oil': 'tab:orange',
    'CO2_gas': 'tab:green',
    'CO2_cement': 'tab:red'
}

# Historische Daten extrahieren
historical_co2 = historical_data[['Year', 'CO2_coal', 'CO2_oil', 'CO2_gas', 'CO2_cement']]

# Subplots: 1 Zeile, 2 Spalten
fig, axes = plt.subplots(1, 2, figsize=(16, 6), sharey=True)

# 1. Plot – Business as Usual
for col in colors.keys():
    # Historische Werte
    axes[0].plot(historical_co2['Year'], historical_co2[col], linestyle='-', label=col.replace('CO2_', '').capitalize(), color=colors[col])
    # Prognose
    axes[0].plot(df_bau_direct['Year'], df_bau_direct[col], linestyle='--', color=colors[col])

axes[0].set_title('Szenario A – Business as Usual')
axes[0].set_xlabel('Jahr')
axes[0].set_ylabel('CO₂-Emissionen [Mt]')
axes[0].legend()
axes[0].grid(True, linestyle='--', alpha=0.5)

# 2. Plot – Mit Maßnahmen
for col in colors.keys():
    # Historische Werte
    axes[1].plot(historical_co2['Year'], historical_co2[col], linestyle='-', label=col.replace('CO2_', '').capitalize(), color=colors[col])
    # Prognose
    axes[1].plot(df_mea_direct['Year'], df_mea_direct[col], linestyle='--', color=colors[col])

axes[1].set_title('Szenario B – Mit Maßnahmen')
axes[1].set_xlabel('Jahr')
axes[1].legend()
axes[1].grid(True, linestyle='--', alpha=0.5)

# Layout und Titel
plt.suptitle('Vergleich der CO₂-Komponenten mit historischen Werten (India)', fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
# Out:
# Epoch 1/500
# /Users/jana/.pyenv/versions/3.10.15/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0512 - mae: 0.1713 - val_loss: 0.2171 - val_mae: 0.4334
# Epoch 2/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0150 - mae: 0.0967 - val_loss: 0.1938 - val_mae: 0.3985
# Epoch 3/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0105 - mae: 0.0806 - val_loss: 0.2313 - val_mae: 0.4504
# Epoch 4/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0091 - mae: 0.0705 - val_loss: 0.2171 - val_mae: 0.4347
# Epoch 5/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0077 - mae: 0.0575 - val_loss: 0.1925 - val_mae: 0.3996
# Epoch 6/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068 - mae: 0.0632 - val_loss: 0.1903 - val_mae: 0.4012
# Epoch 7/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0094 - mae: 0.0756 - val_loss: 0.1702 - val_mae: 0.3814
# Epoch 8/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0113 - mae: 0.0682 - val_loss: 0.1454 - val_mae: 0.3436
# Epoch 9/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0044 - mae: 0.0491 - val_loss: 0.1411 - val_mae: 0.3391
# Epoch 10/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0064 - mae: 0.0575 - val_loss: 0.1431 - val_mae: 0.3420
# Epoch 11/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0048 - mae: 0.0527 - val_loss: 0.0805 - val_mae: 0.2412
# Epoch 12/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0067 - mae: 0.0600 - val_loss: 0.1249 - val_mae: 0.3241
# Epoch 13/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mae: 0.0605 - val_loss: 0.0895 - val_mae: 0.2641
# Epoch 14/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0045 - mae: 0.0532 - val_loss: 0.1201 - val_mae: 0.3175
# Epoch 15/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mae: 0.0492 - val_loss: 0.1197 - val_mae: 0.3186
# Epoch 16/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0058 - mae: 0.0558 - val_loss: 0.0961 - val_mae: 0.2794
# Epoch 17/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0060 - mae: 0.0526 - val_loss: 0.0691 - val_mae: 0.2240
# Epoch 18/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0046 - mae: 0.0547 - val_loss: 0.0738 - val_mae: 0.2403
# Epoch 19/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0025 - mae: 0.0368 - val_loss: 0.0888 - val_mae: 0.2698
# Epoch 20/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0042 - mae: 0.0495 - val_loss: 0.0853 - val_mae: 0.2591
# Epoch 21/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0034 - mae: 0.0402 - val_loss: 0.1170 - val_mae: 0.3119
# Epoch 22/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0042 - mae: 0.0453 - val_loss: 0.0910 - val_mae: 0.2714
# Epoch 23/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0041 - mae: 0.0463 - val_loss: 0.1012 - val_mae: 0.2892
# Epoch 24/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0067 - mae: 0.0568 - val_loss: 0.1603 - val_mae: 0.3724
# Epoch 25/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0043 - mae: 0.0478 - val_loss: 0.1131 - val_mae: 0.2994
# Epoch 26/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0040 - mae: 0.0522 - val_loss: 0.1007 - val_mae: 0.2833
# Epoch 27/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0035 - mae: 0.0456 - val_loss: 0.1143 - val_mae: 0.3102
# Epoch 28/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0037 - mae: 0.0452 - val_loss: 0.0946 - val_mae: 0.2746
# Epoch 29/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0055 - mae: 0.0581 - val_loss: 0.0808 - val_mae: 0.2484
# Epoch 30/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0045 - mae: 0.0454 - val_loss: 0.0972 - val_mae: 0.2813
# Epoch 31/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0033 - mae: 0.0396 - val_loss: 0.0726 - val_mae: 0.2312
# Epoch 32/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0042 - mae: 0.0467 - val_loss: 0.0770 - val_mae: 0.2436
# Epoch 33/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0040 - mae: 0.0509 - val_loss: 0.0505 - val_mae: 0.1829
# Epoch 34/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mae: 0.0595 - val_loss: 0.0821 - val_mae: 0.2588
# Epoch 35/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0039 - mae: 0.0450 - val_loss: 0.0726 - val_mae: 0.2377
# Epoch 36/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0036 - mae: 0.0405 - val_loss: 0.0863 - val_mae: 0.2657
# Epoch 37/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0042 - mae: 0.0452 - val_loss: 0.0605 - val_mae: 0.2071
# Epoch 38/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0028 - mae: 0.0402 - val_loss: 0.0820 - val_mae: 0.2553
# Epoch 39/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0026 - mae: 0.0349 - val_loss: 0.0845 - val_mae: 0.2614
# Epoch 40/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0305 - val_loss: 0.0633 - val_mae: 0.2162
# Epoch 41/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0030 - mae: 0.0372 - val_loss: 0.0641 - val_mae: 0.2169
# Epoch 42/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - mae: 0.0314 - val_loss: 0.0785 - val_mae: 0.2487
# Epoch 43/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0039 - mae: 0.0413 - val_loss: 0.0749 - val_mae: 0.2406
# Epoch 44/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - mae: 0.0347 - val_loss: 0.0680 - val_mae: 0.2276
# Epoch 45/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - mae: 0.0354 - val_loss: 0.0619 - val_mae: 0.2134
# Epoch 46/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0027 - mae: 0.0374 - val_loss: 0.0521 - val_mae: 0.1908
# Epoch 47/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0028 - mae: 0.0378 - val_loss: 0.0411 - val_mae: 0.1599
# Epoch 48/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015 - mae: 0.0297 - val_loss: 0.0605 - val_mae: 0.2137
# Epoch 49/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0034 - mae: 0.0432 - val_loss: 0.0378 - val_mae: 0.1515
# Epoch 50/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0031 - mae: 0.0399 - val_loss: 0.0642 - val_mae: 0.2225
# Epoch 51/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0028 - mae: 0.0352 - val_loss: 0.0549 - val_mae: 0.1979
# Epoch 52/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0031 - mae: 0.0385 - val_loss: 0.0339 - val_mae: 0.1419
# Epoch 53/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0030 - mae: 0.0364 - val_loss: 0.0651 - val_mae: 0.2197
# Epoch 54/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0033 - mae: 0.0400 - val_loss: 0.0388 - val_mae: 0.1512
# Epoch 55/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - mae: 0.0349 - val_loss: 0.0442 - val_mae: 0.1696
# Epoch 56/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023 - mae: 0.0331 - val_loss: 0.0620 - val_mae: 0.2163
# Epoch 57/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0029 - mae: 0.0359 - val_loss: 0.0480 - val_mae: 0.1728
# Epoch 58/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0032 - mae: 0.0360 - val_loss: 0.0696 - val_mae: 0.2286
# Epoch 59/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - mae: 0.0335 - val_loss: 0.0666 - val_mae: 0.2235
# Epoch 60/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023 - mae: 0.0319 - val_loss: 0.0696 - val_mae: 0.2295
# Epoch 61/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0288 - val_loss: 0.0591 - val_mae: 0.2035
# Epoch 62/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - mae: 0.0330 - val_loss: 0.0455 - val_mae: 0.1718
# Epoch 63/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0029 - mae: 0.0372 - val_loss: 0.0675 - val_mae: 0.2294
# Epoch 64/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - mae: 0.0309 - val_loss: 0.0398 - val_mae: 0.1594
# Epoch 65/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023 - mae: 0.0357 - val_loss: 0.0584 - val_mae: 0.2081
# Epoch 66/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0044 - mae: 0.0402 - val_loss: 0.0547 - val_mae: 0.1959
# Epoch 67/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0027 - mae: 0.0378 - val_loss: 0.0529 - val_mae: 0.1907
# Epoch 68/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012 - mae: 0.0268 - val_loss: 0.0482 - val_mae: 0.1801
# Epoch 69/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0039 - mae: 0.0446 - val_loss: 0.0689 - val_mae: 0.2296
# Epoch 70/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016 - mae: 0.0280 - val_loss: 0.0569 - val_mae: 0.1988
# Epoch 71/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020 - mae: 0.0329 - val_loss: 0.0700 - val_mae: 0.2282
# Epoch 72/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013 - mae: 0.0263 - val_loss: 0.0797 - val_mae: 0.2524
# Epoch 73/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023 - mae: 0.0315 - val_loss: 0.0494 - val_mae: 0.1854
# Epoch 74/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - mae: 0.0353 - val_loss: 0.0553 - val_mae: 0.1955
# Epoch 75/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014 - mae: 0.0253 - val_loss: 0.0546 - val_mae: 0.1932
# Epoch 76/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0027 - mae: 0.0357 - val_loss: 0.0620 - val_mae: 0.2156
# Epoch 77/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - mae: 0.0335 - val_loss: 0.0722 - val_mae: 0.2381
# Epoch 78/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0038 - mae: 0.0447 - val_loss: 0.0518 - val_mae: 0.1879
# Epoch 79/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0032 - mae: 0.0364 - val_loss: 0.0704 - val_mae: 0.2320
# Epoch 80/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013 - mae: 0.0286 - val_loss: 0.0587 - val_mae: 0.2071
# Epoch 81/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013 - mae: 0.0262 - val_loss: 0.0599 - val_mae: 0.2094
# Epoch 82/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016 - mae: 0.0281 - val_loss: 0.0534 - val_mae: 0.1919
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# CO2_coal:
#   Mittlere absolute Abweichung (MAE): 323.70
#   Root Mean Squared Error (RMSE): 370.09
#   Bestimmtheitsmaß (R²): -1.055
#
# CO2_oil:
#   Mittlere absolute Abweichung (MAE): 20.39
#   Root Mean Squared Error (RMSE): 27.58
#   Bestimmtheitsmaß (R²): 0.882
#
# CO2_gas:
#   Mittlere absolute Abweichung (MAE): 23.25
#   Root Mean Squared Error (RMSE): 27.73
#   Bestimmtheitsmaß (R²): -1.844
#
# CO2_cement:
#   Mittlere absolute Abweichung (MAE): 16.01
#   Root Mean Squared Error (RMSE): 18.63
#   Bestimmtheitsmaß (R²): 0.163
#
#                  Feature     Startwert       Endwert  Jahreswachstum
# 0                    GDP  6.065864e+12  7.999672e+12            7.16
# 1             Population  1.278576e+09  1.343875e+09            1.25
# 2         Primary_energy  6.906590e+03  8.271800e+03            4.61
# 3       Energy_intensity  1.140000e+00  1.040000e+00           -2.35
# 4               CO2_coal  1.276380e+03  1.551260e+03            5.00
# 5                CO2_oil  4.969400e+02  6.325600e+02            6.22
# 6                CO2_gas  1.106900e+02  1.189200e+02            1.81
# 7             CO2_cement  1.078200e+02  1.210500e+02            2.94
# 8   Urban_population_pct  3.164000e+01  3.319000e+01            1.20
# 9        Trade_share_GDP  5.509000e+01  4.095000e+01           -7.15
# 10     GDP_growth_annual  5.690000e+00  7.780000e+00            8.11
#
# Szenario A – Business as Usual (direkte Entwicklung):
#  Year    CO2_total    CO2_coal     CO2_oil    CO2_gas  CO2_cement
#  2018  2546.402178 1628.818800  671.903108 121.074488  124.605782
#  2019  2675.490349 1710.259740  713.695481 123.265936  128.269192
#  2020  2811.397423 1795.772727  758.087340 125.497050  132.040306
#  2021  2954.492573 1885.561363  805.240372 127.768546  135.922291
#  2022  3105.165319 1979.839432  855.326323 130.081157  139.918406
#  2023  3263.826658 2078.831403  908.527621 132.435626  144.032008
#  2024  3430.910272 2182.772973  965.038039 134.832711  148.266549
#  2025  3606.873795 2291.911622 1025.063405 137.273183  152.625585
#  2026  3792.200157 2406.507203 1088.822349 139.757828  157.112777
#  2027  3987.398999 2526.832563 1156.547099 142.287444  161.731893
#  2028  4193.008177 2653.174191 1228.484328 144.862847  166.486811
#  2029  4409.595342 2785.832901 1304.896053 147.484865  171.381523
#  2030  4637.759614 2925.124546 1386.060588 150.154341  176.420140
#  2031  4878.133356 3071.380773 1472.273557 152.872134  181.606892
#  2032  5131.384038 3224.949812 1563.848972 155.639120  186.946134
#  2033  5398.216219 3386.197302 1661.120378 158.456188  192.442351
#  2034  5679.373634 3555.507168 1764.442065 161.324245  198.100156
#  2035  5975.641402 3733.282526 1874.190362 164.244214  203.924300
#  2036  6287.848363 3919.946652 1990.765002 167.217034  209.919675
#  2037  6616.869546 4115.943985 2114.590585 170.243662  216.091313
#  2038  6963.628774 4321.741184 2246.118120 173.325073  222.444398
#  2039  7329.101430 4537.828243 2385.826667 176.462256  228.984263
#  2040  7714.317365 4764.719656 2534.225086 179.656223  235.716400
#  2041  8120.363988 5002.955638 2691.853886 182.908001  242.646463
#  2042  8548.389522 5253.103420 2859.287198 186.218636  249.780269
#  2043  8999.606454 5515.758591 3037.134861 189.589193  257.123809
#  2044  9475.295176 5791.546521 3226.044650 193.020757  264.683248
#  2045  9976.807843 6081.123847 3426.704627 196.514433  272.464936
#  2046 10505.572443 6385.180039 3639.845655 200.071344  280.475405
#  2047 11063.097113 6704.439041 3866.244054 203.692636  288.721382
#  2048 11650.974691 7039.660993 4106.724435 207.379472  297.209791
#  2049 12270.887537 7391.644043 4362.162694 211.133041  305.947758
#  2050 12924.612631 7761.226245 4633.489214 214.954549  314.942623
#
# Szenario B – Mit Maßnahmen (direkte Eingriffe):
#  Year   CO2_total    CO2_coal    CO2_oil    CO2_gas  CO2_cement
#  2018 2392.757880 1520.230880 632.558000 118.922000  121.047000
#  2019 2362.353262 1489.826262 632.558000 118.922000  121.047000
#  2020 2332.556737 1460.029737 632.558000 118.922000  121.047000
#  2021 2303.356142 1430.829142 632.558000 118.922000  121.047000
#  2022 2274.739560 1402.212560 632.558000 118.922000  121.047000
#  2023 2246.695308 1374.168308 632.558000 118.922000  121.047000
#  2024 2219.211942 1346.684942 632.558000 118.922000  121.047000
#  2025 2178.744782 1319.751243 623.069630 118.922000  117.001909
#  2026 2139.093799 1293.356218 613.723586 118.922000  113.091995
#  2027 2100.241566 1267.489094 604.517732 118.922000  109.312740
#  2028 2062.171057 1242.139312 595.449966 118.922000  105.659779
#  2029 2024.865633 1217.296526 586.518216 118.922000  102.128891
#  2030 1986.778853 1192.950595 577.720443 117.391818   98.715996
#  2031 1949.444697 1169.091584 569.054636 115.881325   95.417152
#  2032 1912.847383 1145.709752 560.518817 114.390268   92.228547
#  2033 1876.971485 1122.795557 552.111035 112.918396   89.146497
#  2034 1841.801920 1100.339646 543.829369 111.465463   86.167442
#  2035 1807.323946 1078.332853 535.671929 110.031226   83.287939
#  2036 1773.523150 1056.766196 527.636850 108.615442   80.504662
#  2037 1740.385440 1035.630872 519.722297 107.217876   77.814396
#  2038 1707.897040 1014.918254 511.926462 105.838292   75.214031
#  2039 1676.044479  994.619889 504.247565 104.476460   72.700564
#  2040 1644.814585  974.727492 496.683852 103.132150   70.271092
#  2041 1614.194479  955.232942 489.233594 101.805138   67.922806
#  2042 1584.171567  936.128283 481.895090 100.495200   65.652994
#  2043 1554.733532  917.405717 474.666664  99.202118   63.459033
#  2044 1525.868330  899.057603 467.546664  97.925674   61.338389
#  2045 1497.564181  881.076451 460.533464  96.665654   59.288612
#  2046 1469.809564  863.454922 453.625462  95.421847   57.307333
#  2047 1442.593212  846.185823 446.821080  94.194044   55.392264
#  2048 1415.904102  829.262107 440.118764  92.982039   53.541192
#  2049 1389.731454  812.676865 433.516982  91.785629   51.751978
#  2050 1364.064724  796.423327 427.014228  90.604614   50.022555
#
#  Prognosedateien gespeichert in: ../data/results/szenario_prognose_india_lsmt/
